# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshyajain45/python/blob/main/Practice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
students = [
    {"name": "Rahul", "marks": 72},
    {"name": "Priya", "marks": 85},
    {"name": "Arjun", "marks": 40},
    {"name": "Sneha", "marks": 91},
    {"name": "Vikram", "marks": 55},
]

a = 0
for i in students:
    a = a + i["marks"]

print(a / len(students))
# Out:
# 68.6

# %%
students = [
    {"name": "Rahul", "marks": 72},
    {"name": "Priya", "marks": 85},
    {"name": "Arjun", "marks": 40},
    {"name": "Sneha", "marks": 91},
    {"name": "Vikram", "marks": 55},
]

a = []
for i in students:
    if i["marks"] >= 50:
        a.append(i["name"])

print(a)
# Out:
# ['Rahul', 'Priya', 'Sneha', 'Vikram']

# %%
students = [
    {"name": "Rahul", "marks": 72},
    {"name": "Priya", "marks": 85},
    {"name": "Arjun", "marks": 40},
    {"name": "Sneha", "marks": 91},
    {"name": "Vikram", "marks": 55},
]

a = []
for i in students:
    if i["marks"] <= 50:
        a.append(i["name"])

print(a)
# Out:
# ['Arjun']

# %%
students = [
    {"name": "Rahul", "marks": 72},
    {"name": "Priya", "marks": 85},
    {"name": "Arjun", "marks": 40},
    {"name": "Sneha", "marks": 91},
    {"name": "Vikram", "marks": 55},
]

a = 0
b = ""

for i in students:
    if i["marks"] > a:
        a = i["marks"]
        b = i["name"]

print(b, a)
# Out:
# Sneha 91

# %%
scores = [
    ("Rohit", 83),
    ("Virat", 45),
    ("Dhoni", 67),
    ("Hardik", 32),
    ("Bumrah", 12),
    ("Shubman", 91),
]

a = 0
for i, j in scores:
    a = a + j

print(a)
# Out:
# 330

# %%
scores = [
    ("Rohit", 83),
    ("Virat", 45),
    ("Dhoni", 67),
    ("Hardik", 32),
    ("Bumrah", 12),
    ("Shubman", 91),
]

a = 0
b = ""

for i, j in scores:
    if j > a:
        a = j
        b = i

print(a, b)
# Out:
# 91 Shubman

# %%
scores = [
    ("Rohit", 83),
    ("Virat", 45),
    ("Dhoni", 67),
    ("Hardik", 32),
    ("Bumrah", 12),
    ("Shubman", 91),
]

a = []
b = []

for i, j in scores:
    if j >= 50:
        b.append(j)
        a.append(i)

a = list(zip(a, b))

print(a)
# Out:
# [('Rohit', 83), ('Dhoni', 67), ('Shubman', 91)]

# %%
scores = [
    ("Rohit", 83),
    ("Virat", 45),
    ("Dhoni", 67),
    ("Hardik", 32),
    ("Bumrah", 12),
    ("Shubman", 91),
]

a = 0
for i, j in scores:
    a = j + a

print(a / len(scores))
# Out:
# 55.0

# %%
rf = {"Amit", "Priya", "Rohan", "Sneha", "Karan"}
pf = {"Rohan", "Sneha", "Ankit", "Divya"}

c = []

for i in rf:
    for j in pf:
        if i == j:
            c.append(i)

print(c)
# Out:
# ['Rohan', 'Sneha']

# %%
rf = {"Amit", "Priya", "Rohan", "Sneha", "Karan"}
pf = {"Rohan", "Sneha", "Ankit", "Divya"}

d = []

for i in rf:
    if i not in pf:
        print(i)
# Out:
# Amit
# Priya
# Karan

# %%
rf = {"Amit", "Priya", "Rohan", "Sneha", "Karan"}
pf = {"Rohan", "Sneha", "Ankit", "Divya"}

c = set()

for i in rf:
    for j in pf:
        c.add(i)
        c.add(j)

print(c)
# Out:
# {'Amit', 'Sneha', 'Divya', 'Priya', 'Rohan', 'Ankit', 'Karan'}

# %%
rf = {"Amit", "Priya", "Rohan", "Sneha", "Karan"}
pf = {"Rohan", "Sneha", "Ankit", "Divya"}

c = set()

for i in rf:
    for j in pf:
        c.add(i)
        c.add(j)

print(len(c))
# Out:
# 7

# %%
pb = {
    "Rahul": "9876543210",
    "Priya": "9123456789",
    "Arjun": "9988776655",
}

pb.update({"sneha": "9001122334"})
print(pb)
# Out:
# {'Rahul': '9876543210', 'Priya': '9123456789', 'Arjun': '9988776655', 'sneha': '9001122334'}

# %%
pb = {
    "Rahul": "9876543210",
    "Priya": "9123456789",
    "Arjun": "9988776655",
}

for i, j in pb.items():
    if i == "Priya":
        print(j)
# Out:
# 9123456789

# %%
pb = {
    "Rahul": "9876543210",
    "Priya": "9123456789",
    "Arjun": "9988776655",
}

pb.pop("Arjun")
print(pb)
# Out:
# {'Rahul': '9876543210', 'Priya': '9123456789'}

# %%
pb = {
    "Rahul": "9876543210",
    "Priya": "9123456789",
    "sneha": "9001122334",
}

a = []

for i in pb:
    a.append(i)

a.sort()
print(a)
# Out:
# ['Priya', 'Rahul', 'sneha']

# %%
pb = {
    "Rahul":  "9876543210",
    "Priya":  "9123456789",
    "sneha": "9001122334",
}

contact = pb.get("Virat")

if contact:
    print(contact)
else:
    print("Contact not found!")
# Out:
# Contact not found!

# %%
class Student:
    def __init__(self, name, roll_no, marks):
        self.name = name
        self.roll_no = roll_no
        self.marks = marks

    def get_grade(self):
        if self.marks >= 80:
            return "A"
        elif self.marks >= 60:
            return "B"
        else:
            return "C"

    def display(self):
        print("Name:",{self.name})
        print("Roll No:", {self.roll_no})
        print("Marks:", {self.marks})
        print("Grade:", {self.get_grade()})


class Topper(Student):
    def __init__(self, name, roll_no, marks):
        super().__init__(name, roll_no, marks)

    def get_scholarship(self):
        if self.marks >= 90:
            print("₹10,000")
        else:
            print("No scholarship")


s1 = Student("Rahul", 101, 75)
s1.display()
print("------")

t1 = Topper("sneha", 102, 95)
t1.display()
t1.get_scholarship()
# Out:
# Name: {'Rahul'}
# Roll No: {101}
# Marks: {75}
# Grade: {'B'}
# ------
# Name: {'sneha'}
# Roll No: {102}
# Marks: {95}
# Grade: {'A'}
# ₹10,000
