# %% [markdown]
# <a href="https://colab.research.google.com/github/lakshyajain45/python/blob/main/Day6Task.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#01 List Comprehension Masterclass 🧩
scores = [45, 82, 91, 33, 67, 55, 78, 29, 95, 61]
names  = ["Rahul", "priya", "ARJUN", "sneha", "Vikram"]
a=[x for x in scores if x >= 60]
print(a)
b=[x**2 for x in scores]
print(b)
c=["A" if x>=80 else "B" if x>=60 else "C" for x in scores]
print(c)
d=[x.title() for x in names]
print(d)
e=[x for x in scores if x >= 60 and x%2==0]
print(e)
# Out:
# [82, 91, 67, 78, 95, 61]
# [2025, 6724, 8281, 1089, 4489, 3025, 6084, 841, 9025, 3721]
# ['C', 'A', 'A', 'C', 'B', 'C', 'B', 'C', 'A', 'B']
# ['Rahul', 'Priya', 'Arjun', 'Sneha', 'Vikram']
# [82, 78]

# %%
#2 FizzBuzz — The Classic 🎯
def fizzbuzz(n):
  a=["FizzBuzz" if i%15==0 else "Fizz" if i%3==0 else "Buzz" if i%5==0 else str(i) for i in range(1, n+1)]
  print(a)
  for i in range(1, n + 1):
      if i%3==0 and i%5==0:
        print('FizzBuzz')
      elif i%3==0:
        print('Fizz')
      elif i%5==0:
        print('Buzz')
      else:
        print(i)
fizzbuzz(20)
# Out:
# ['1', '2', 'Fizz', '4', 'Buzz', 'Fizz', '7', '8', 'Fizz', 'Buzz', '11', 'Fizz', '13', '14', 'FizzBuzz', '16', '17', 'Fizz', '19', 'Buzz']
# 1
# 2
# Fizz
# 4
# Buzz
# Fizz
# 7
# 8
# Fizz
# Buzz
# 11
# Fizz
# 13
# 14
# FizzBuzz
# 16
# 17
# Fizz
# 19
# Buzz

# %%
#3 Caesar Cipher 🔑
def encrypt(text, shift):
    result = ""
    for c in text:
      if c.isupper():
        result+=chr((ord(c) - ord('A') + shift) % 26 + ord('A'))
      elif c.islower():
        result+=chr((ord(c) - ord('a') + shift) % 26 + ord('a'))
      else:
        result += c
    return result

def decrypt(text, shift):
  return encrypt(text, 26 - shift)

print(encrypt("Hello World", 3))
print(decrypt("Khoor Zruog", 3))
# Out:
# Khoor Zruog
# Hello World

# %%
#4 Number to Words 🔢➡️📝
ones  = ["","One","Two","Three","Four","Five",
         "Six","Seven","Eight","Nine","Ten",
         "Eleven","Twelve","Thirteen","Fourteen","Fifteen",
         "Sixteen","Seventeen","Eighteen","Nineteen"]
tens  = ["","","Twenty","Thirty","Forty","Fifty",
         "Sixty","Seventy","Eighty","Ninety"]

def to_words(n):
    if n == 0:
      return "Zero"
    if n < 20:
      return ones[n]
    if n < 100:
      return tens[n//10] + " " + ones[n%10]
    if n < 1000:
      return ones[n//100] + " Hundred " + to_words(n%100)


for num in [0, 7, 15, 42, 100, 305, 999]:
    print(f"{num} → {to_words(num)}")
# Out:
# 0 → Zero
# 7 → Seven
# 15 → Fifteen
# 42 → Forty Two
# 100 → One Hundred Zero
# 305 → Three Hundred Five
# 999 → Nine Hundred Ninety Nine

# %%
#5 Bank Account — Full OOP 🏦
class BankAccount:
    def __init__(self, owner, balance=0):
      self.owner    = owner
      self.balance  = balance
      self.history  = []

    def deposit(self, amount):
      self.balance=self.balance+amount
      self.history.append(f"+ ₹{amount}")
      return self.balance

    def withdraw(self, amount):
      if amount<=self.balance:
        self.balance=self.balance-amount
        self.history.append(f"- ₹{amount}")
        return self.balance
      else:
        print("Insufficient balance")
        return self.balance
      return self.balance

    def statement(self):
      print("owner name:",self.owner)
      print("balance:",self.balance)
      print("history:",self.history)
acc = BankAccount("Rahul", 1000)
acc.deposit(500)
acc.withdraw(200)
acc.withdraw(5000)   # should fail
acc.statement()
# Out:
# Insufficient balance
# owner name: Rahul
# balance: 1300
# history: ['+ ₹500', '- ₹200']
